# %%
email = "Amit_ml@gmail.edu"

if email.count("@") == 1 and "." in email.split("@")[1]:
    username = email.split("@")[0]
    domain = email.split("@")[1].split(".")[0]
    print("Username:", username)
    print("Domain:", domain)
    if email.endswith(".com"):
        print("Commercial Domain")
    elif email.endswith(".edu"):
        print("Educational Domain")
    else:
        print("Other Domain")
else:
    print("Invalid email")
# Out:
# Username: Amit_ml
# Domain: gmail
# Educational Domain

# %%
word1 = "mocleW"[::-1]
word2 = "EPGTQ"
decoded_message = word1 + " " + word2
print(decoded_message)
# Out:
# Welcom EPGTQ

# %%
word1 = "gnirts"[::-1].capitalize()
word2 = "PLEU"
decoded_message = word1 + " " + word2
print(decoded_message)
# Out:
# String PLEU

# %%
word1 = "yalpstcejorp"[::-1]
word2 = "APTOV"
decoded_message = word1 + " " + word2
print(decoded_message)
# Out:
# projectsplay APTOV
