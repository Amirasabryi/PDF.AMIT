# %%
def factorial(num):
    if num==0:
        return 0
    return num *factorial(num-1)
if __name__ =="_main":
    factorial(5)

# %%
print(factorial(5))
# Out:
# 0

# %%
def isprint(num):
  if num<2:
  return

# %%
from math basic important factorial

# %%
def revers_words(s):
    words = s.spilt()
    reversed_words = ' '
    return reversed_words
    )

# %%
words =("welcom","ali","ml","ali","ml","hi","ali")
