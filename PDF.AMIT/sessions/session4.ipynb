# %%
def function_1():
    print("welcom depi")

# %%
def user_info(name,age):
    prin(f"my name is {name},mu age is {age}")

# %%
def user_info(name, age):
    """
    brief description of your function

    Args:
        param_name(str): this is string input for name of user
        param_age(int): this is int input for the user age

    Returns:
        return_type: print the description for user info
    Examples:
        >>> function
    """
    print(f"my name is {name}, my age is {age}")

# %%
# No import needed - user_info is already defined in the cells above
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from info_user import user_info
#
# ModuleNotFoundError: No module named 'info_user'
