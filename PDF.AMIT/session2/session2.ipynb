# %%
name = "Mira"
age = 25
print(name)
print(age)
message = f"Hello, my name is {name} and I am {age} years old."
# Out:
# Mira
# 25

# %%
name = "Mira"
age = 25 
print ("my name is {} and i am {} years old".format(name,age))
# Out:
# my name is Mira and i am 25 years old

# %%
text = "python"
print (text[0])
print (text[1])
print (text[-3])
# Out:
# p
# y
# h

# %%
text = "python"
print (text[:-1])
# Out:
# pytho

# %%
text = "abcdefghij "
print (text[5:])
# Out:
# fghij

# %%
text = "abcdefghij "
print (text[::2])
# Out:
# acegi

# %%
text = "abcdefghij "
print   (text[-4:])
# Out:
# hij

# %%
name = "mira"
print (name . upper())
print (name.lower())
# Out:
# MIRA
# mira

# %%
hobbies = "reading"
new_hobbies = hobbies.replace("reading", "writing")
print(new_hobbies)
# Out:
# writing

# %%
data = "appel,banana,orang"
fruits = data.split(",")
print (fruits)
# Out:
# ['appel', 'banana', 'orang']

# %%
msg = "banana"
print(msg.count("a"))
# Out:
# 3

# %%
words =["welcome" ," to ","python"]
result = " " . join(words)
print(result)
# Out:
# welcome  to  python

# %%
file_name =" report.pdf"
print (file_name.startswith("report"))
print (file_name.endswith (".pdf"))
# Out:
# False
# True

# %%
my_list = ["appel", "banana",20,30,"math"]
print (my_list[0])
print (my_list[3])
# Out:
# appel
# 30

# %%
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]
print (days[0])
# Out:
# Monday

# %%
numbers = {1,2,2,2,2,3,4,4,5,6}
print (numbers)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
student = {
    "name": "Mira",
    "age": 25,
    "city": "New York"

}
print (student)
# Out:
# {'name': 'Mira', 'age': 25, 'city': 'New York'}

# %%
score = 85
if score >=90:
    print ("A")
elif score >=80:
    print ("B")
else:
    print ("C")
# Out:
# B

# %%
user_email = "amir_ai@gmail.com"
print(user_email)

code_msg = "x9876543210y"
print(code_msg[::2])

tools = ["vscode","ros","python","python"]
tools.remove("python")
tools= {"vscode","ros","python","python"}
print(tools)

location = (30.04, 31.23)
print(location)

project = {
    "name": "smart reception robot",
    "status": "in progress",
    "team_size": "4"
}
print(project)

team_size = 5
if team_size > 5:
    print("large team")
elif team_size == 5:
    print("medium team")
else:
    print("small team")
# Out:
# amir_ai@gmail.com
# x86420
# {'ros', 'vscode', 'python'}
# (30.04, 31.23)
# {'name': 'smart reception robot', 'status': 'in progress', 'team_size': '4'}
# medium team
